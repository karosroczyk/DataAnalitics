# %%
from sqlalchemy import create_engine
from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy import select
from sqlalchemy import join
from sqlalchemy import func

# %% [markdown]
# Zadanie 1. Connection to SQLAlchemy with database

# %%
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"
db = create_engine(db_string)

# %% [markdown]
# Zadanie 2. Finding relations between tables

# %% [markdown]
# a) INNER JOIN ON staff and country

# %%
metadata = MetaData()

staff = Table('staff', metadata , autoload=True, autoload_with=db)
address = Table('address', metadata , autoload=True, autoload_with=db)
city = Table('city', metadata , autoload=True, autoload_with=db)
country = Table('country', metadata , autoload=True, autoload_with=db)

actor = Table('actor', metadata , autoload=True, autoload_with=db)
film_actor = Table('film_actor', metadata , autoload=True, autoload_with=db)
film = Table('film', metadata , autoload=True, autoload_with=db)
language = Table('language', metadata , autoload=True, autoload_with=db)

film_category = Table('film_category', metadata , autoload=True, autoload_with=db)
inventory = Table('inventory', metadata , autoload=True, autoload_with=db)
rental = Table('rental', metadata , autoload=True, autoload_with=db)

# %%
conn = db.connect()
first_sel = country.join(city, country.columns.country_id == city.columns.country_id)
second_sel = first_sel.join(address, first_sel.columns.city_city_id == address.columns.city_id)
third_sel = second_sel.join(staff, second_sel.columns.address_address_id == staff.columns.address_id)
stmt = select([second_sel]).select_from(third_sel)

result = conn.execute(stmt)
result.fetchall()
# Out:
# [(20, 'Canada', datetime.datetime(2006, 2, 15, 9, 44), 300, 'Lethbridge', 20, datetime.datetime(2006, 2, 15, 9, 45, 25), 3, '23 Workhaven Lane', None, 'Alberta', 300, '', '14033335568', datetime.datetime(2006, 2, 15, 9, 45, 30)),
#  (8, 'Australia', datetime.datetime(2006, 2, 15, 9, 44), 576, 'Woodridge', 8, datetime.datetime(2006, 2, 15, 9, 45, 25), 4, '1411 Lillydale Drive', None, 'QLD', 576, '', '6172235589', datetime.datetime(2006, 2, 15, 9, 45, 30))]

# %% [markdown]
# b) INNER JOIN ON actor, film and language

# %%
conn = db.connect()
first_sel = actor.join(film_actor, actor.columns.actor_id == film_actor.columns.actor_id)
second_sel = first_sel.join(film, first_sel.columns.film_actor_film_id == film.columns.film_id)
third_sel = second_sel.join(language, second_sel.columns.film_language_id == language.columns.language_id)
stmt = select([second_sel]).select_from(third_sel)
print(stmt)
result = conn.execute(stmt)
result.fetchall()
# Out:
# SELECT actor.actor_id, actor.first_name, actor.last_name, actor.last_update, film_actor.actor_id, film_actor.film_id, film_actor.last_update, film.film_id, film.title, film.description, film.release_year, film.language_id, film.rental_duration, film.rental_rate, film.length, film.replacement_cost, film.rating, film.last_update, film.special_features, film.fulltext
# FROM actor JOIN film_actor ON actor.actor_id = film_actor.actor_id JOIN film ON film_actor.film_id = film.film_id JOIN language ON film.language_id = language.language_id
# ...

# %% [markdown]
# Zadanie 3. How many categories of films we have in the rental ?

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=db)
Session = sessionmaker()
Session.configure(bind=db)
session = Session()

conn = db.connect()
first_sel = rental.join(inventory, rental.columns.inventory_id == inventory.columns.inventory_id)
second_sel = first_sel.join(film, first_sel.columns.inventory_film_id == film.columns.film_id)
third_sel = second_sel.join(film_category, second_sel.columns.film_film_id == film_category.columns.film_id)
sel = select([func.count()]).select_from(third_sel)
#fourth_sel = third_sel.count()

print(third_sel)
stmt = select([second_sel]).select_from(third_sel)
result = conn.execute(stmt)

#session.query(stmt.staff_username, func.count(stmt.staff_username)).group_by(stmt.staff_username).all()

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import func

# create a configured "Session" class
Session = sessionmaker(bind=db)

# create a Session
session = Session()
records = session.query(func.third_sel)

#records_sec = session.query(records).join(film, first_sel.columns.inventory_film_id == film.columns.film_id).all()
for result in records:
   print(result.inventory_id)
